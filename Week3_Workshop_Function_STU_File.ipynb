# %% [markdown]
# <a href="https://colab.research.google.com/github/mairafaq08/test_repo/blob/main/Week3_Workshop_Function_STU_File.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 📝 Hands-On Exercises: Functions in Python

# %%
# @title AI prompt cell

import ipywidgets as widgets
from IPython.display import display, HTML, Markdown,clear_output
from google.colab import ai

dropdown = widgets.Dropdown(
    options=[],
    layout={'width': 'auto'}
)

def update_model_list(new_options):
    dropdown.options = new_options
update_model_list(ai.list_models())

text_input = widgets.Textarea(
    placeholder='Ask me anything....',
    layout={'width': 'auto', 'height': '100px'},
)

button = widgets.Button(
    description='Submit Text',
    disabled=False,
    tooltip='Click to submit the text',
    icon='check'
)

output_area = widgets.Output(
     layout={'width': 'auto', 'max_height': '300px','overflow_y': 'scroll'}
)

def on_button_clicked(b):
    with output_area:
        output_area.clear_output(wait=False)
        accumulated_content = ""
        for new_chunk in ai.generate_text(prompt=text_input.value, model_name=dropdown.value, stream=True):
            if new_chunk is None:
                continue
            accumulated_content += new_chunk
            clear_output(wait=True)
            display(Markdown(accumulated_content))

button.on_click(on_button_clicked)
vbox = widgets.GridBox([dropdown, text_input, button, output_area])

display(HTML("""
<style>
.widget-dropdown select {
    font-size: 18px;
    font-family: "Arial", sans-serif;
}
.widget-textarea textarea {
    font-size: 18px;
    font-family: "Arial", sans-serif;
}
</style>
"""))
display(vbox)

# %% [markdown]
# **Task: Create a function that prints a welcome message.**
#
#          "Hello, welcome to CMP7005, Introduction to Data Analytics!".

# %%
# Solution:
def greet(course):
  print("Hello, welcome to " +course+ " , Introduction to Data Analytics!")
greet("CMP7005")

# %% [markdown]
# **Function with Parameters**
#
# **Task: Create a function that greets someone by name.**
#
#     Hello <name>!,
#     Glad to see you learning Function in Python!
#     Happy Learning!

# %%
# Solution:
def funct(myname):
  print("Hello "+myname+"!,")
  print("Glad to see you learning Function in Python!")
  print("Happy Learning!")

myname = input('Enter your name: ')
funct(myname)

# %% [markdown]
# **Task: Create a function that makes a formatted name tag with first name, last name, and grade.**
#
# **Output:**
# ```
# ==============================
#     HELLO, MY NAME IS
#     Amrita Prasad
#     Level: 7
# ==============================

# %%
# Solution:
def function1(fullname,grade):
  print(f"HELLO, MY NAME IS")
  print(fullname)
  print("Level: "+grade)
fullname = input('Enter Full Name: ')
grade = input('Enter Grade: ')
function1(fullname,grade)

# %% [markdown]
# **Task: Create a function that prints rectangle information with length and width.**
#
# `An example output:`
#
# **Output:**
# ```
# 📐 Rectangle Details 📐
# Length: 5 units
# Width: 3 units
# Area: 15 square units
# Perimeter: 16 units
# ------------------------------

# %%
# Solution:

def info(Len,Wid):
  print("Length: "+ str(Len) +" units")
  print("Width: "+ str(Wid) + " units")
  print("Area: "+ str(Len * Wid) + " square units")
  print("Perimeter: "+ str(2 * (Len + Wid)) +" units")
Len = float(input("Enter Length: "))
Wid = float(input("Enter Width: "))

info(Len,Wid)

# %% [markdown]
# **Function with Return Value**
#
# **Task: Create a function add_numbers(a, b) that returns the sum of two numbers.
# Call the function by inputting with different numbers and print the results.**

# %%
# Solution:

def add_numbers(a, b):
  print("a + b = " + str(a+b))
a = float(input("Enter value a: "))
b = float(input("Enter value b: "))

add_numbers(a, b)
# Out:
# Enter value a: 2
# Enter value b: 3
# a + b = 5.0

# %% [markdown]
# Create a function that calculates the area of a circle and returns it.
#
# `(Area = 3.14 × radius × radius)`
#
# **Output:**
# ```
# Circle area: 78.5
# Larger circle area: 314.0
# Combined area: 78.26

# %%
# Solution:
def circle(radius):
  return(3.14 * radius**2)
  #print("Circle Area: " , (3.14 * radius**2))
  #print("Larger Circle Area: " , (3.14 * ((2*radius)**2)))
  #print("Combined Area: " , (3.14 * radius**2) + (3.14 * (radius)**2,2) )
input_radius = float(input("enter radius: "))
area = circle(input_radius)
large_area = circle(input_radius*2)
print(f"Circle Area: {area}")
print(f"Large Circle Area: {large_area}")
print(f"Combined Area: {area + large_area}")
#circle(radius)
# Out:
# enter radius: 5
# Circle Area: 78.5
# Large Circle Area: 314.0
# Combined Area: 392.5

# %% [markdown]
# ### **Try on your own question:**

# %% [markdown]
# **Task: Create a function that converts Celsius to Fahrenheit and returns the result.**
#
# `(Formula: fahrenheit = celsius × 9/5 + 32)`
#
# **Output:**
# ```
# 25°C = 77.0°F
# Water freezes at 32.0°F
# Water boils at 212.0°F

# %%
# Solution:

def convert(celsius):
  return(celsius * 9/5 + 32)
input_celsius = float(input("Enter Celsius:"))
fahrenheit = convert(input_celsius)
print(f"{input_celsius}°C  = {fahrenheit}°F")
print(f"Water freezes at {convert(0)}°F")
print(f"Water boils at {convert(100)}°F")
# Out:
# Enter Celsius:25
# 25.0°C  = 77.0°F
# Water freezes at 32.0°F
# Water boils at 212.0°F

# %% [markdown]
# ### **Try on your own question:**

# %% [markdown]
# **Task: Create a function that converts kilometers to miles and returns it**
# `(1 kilometer = 0.621 miles)`
#
# **Output:**
# ```
# 5 km = 3.105 miles
# 10 km = 6.21 miles
# Marathon distance: 26.082 miles

# %%
# Solution:

def cnvrt_km(km):
  return(km * 0.621)
input_km = float(input("Enter Kilometer: "))
print(f"{input_km} km = {cnvrt_km(input_km)} miles")
print(f"{2*input_km} km = {2*cnvrt_km(input_km)} miles")
print(f"Marathon distance: {cnvrt_km(42)} miles")
# Out:
# Enter Kilometer: 5
# 5.0 km = 3.105 miles
# 10.0 km = 6.21 miles
# Marathon distance: 26.082 miles

# %% [markdown]
# **Using Default Parameters**
#
# **Task: Write a function power(base, exponent=2) that returns base raised to the power of exponent. Test it by calling power(5) and power(2, 3).**

# %%
# Solution:
def power(b,e):
  return(b ** e)
b = 2 # predefined base value
e = float(input("Enter Exponent value: "))
print(f"Power(2,5) = {power(b,e)}") # any exponent value exp 5
print(f"Power(2,3) = {power(b,3)}") # with base 2 and exponent 3
# Out:
# Enter Exponent value: 5
# Power(2,5) = 32.0
# Power(2,3) = 8

# %% [markdown]
# **Palindrome Checker**
#
# **Task: Write a function is_palindrome(text) that returns True if the string is the same when reversed, otherwise False.**

# %%
# Solution:

def is_palindrome(text):
  return(text == text[::-1])
text = str(input("Enter Palindrom Word: "))
print(f"Is it Pilandrome?: {is_palindrome(text)}")
# Out:
# Enter Palindrom Word: maira
# Is it Pilandrome?: False

# %% [markdown]
# **Multiple Return Values**
#
# **Task: Create a function circle_measurements(radius) that returns both area and circumference of a circle.**
#
# **Use formulas:**
#
# **Area = π × r²**
#
# **Circumference = 2 × π × r**

# %%
# Solution:

def circle_measurements(radius):
  return("Area = " + str(3.14 * radius**2) , "Circumference = "+str(2 * 3.14 * radius))
input_radius2 = float(input("Enter Radius: "))
print(f"{circle_measurements(input_radius2)}")
# Out:
# Enter Radius: 5
# ('Area = 78.5', 'Circumference = 31.400000000000002')

# %% [markdown]
# **Task: Create a function that calculates total and average from three game scores and returns both.**
#
# ```
#
# Output:
#
# Total: 270, , Average: 90.0
# Your total is 280 and average is 93.33333333333333
# ```

# %%
# Solution:
def game(s1,s2,s3):
  total = s1 + s2 + s3
  #total = sum(s1,s2,s3) #not worked due to 2 arguments required
  average = total/3
  return("Your Total is: "+ str(total) ,"and Average is: "+ str(average))
s1,s2,s3 = float(input("S1: ")),float(input("S2: ")),float(input("S3: "))
print(game(s1,s2,s3))
# Out:
# S1: 2
# S2: 3
# S3: 4
# ('Your Total is: 9.0', 'and Average is: 3.0')

# %% [markdown]
# **Task: Create a function that finds both the smallest and largest of three numbers.**
# ```
# Output:
#
# Smallest: 5, Largest: 12
# Range: 25 to 100
# ```

# %%
# Solution:

def min_max(*array):    #all number
    min_val = min(array)
    max_val = max(array)
    return("Smallest: "+ str(min_val) , "Largest: " + str(max_val))
min_val,max_val = min_max(float(input("a: ")),float(input("b: ")),float(input("c: ")))
#min_val,max_val =
print(min_val,max_val)
# Out:
# a: 2
# b: 5
# c: 8
# Smallest: 2.0 Largest: 8.0

# %% [markdown]
# **Task: Create a function that takes a full name and returns first name and last name separately.**
#
# **Output:**
# ```
# Name Amrita Prasad
# First name: Amrita, Last name: Prasad
# Hello Amrita! Your last name is Prasad.

# %%
# Solution:

def full_name(first,last):
  return("First name: " + first, "Last name: "+ last)
first = str(input("Enter First Name: "))
last = str(input("Enter Last Name: "))
print(full_name(first,last))
print(f"Hello {first}! Your last name is {last}.")
# Out:
# Enter First Name: Maira
# Enter Last Name: Afaq
# ('First name: Maira', 'Last name: Afaq')
# Hello Maira! Your last name is Afaq.

# %% [markdown]
# ### **Try on your own question:**

# %% [markdown]
# **Task: What to do: Create a function that returns both area and perimeter of a rectangle.**

# %%
# Solution:
def rectangle(len,wid):
  return("Area = " + str(len * wid) , "Perimeter = "+str(2 * (len + wid)))
len = float(input("Enter Length: "))
wid = float(input("Enter Width: "))
print(rectangle(len,wid))
# Out:
# Enter Length: 3
# Enter Width: 6
# ('Area = 18.0', 'Perimeter = 18.0')

# %% [markdown]
# **Functions with Arbitrary Arguments:**

# %% [markdown]
# **Task: Create a function that can add any amount of numbers together**

# %%
# Solution:
def add_numbers(*args):
  return("Sum of Values: 4"+str(sum(args)))
#args = [1,2,3,4,5] ## given values
args = [float(input("n1: ")),float(input("n2: ")),float(input("n3: "))]  ## User inputs
print(add_numbers(*args))
# Out:
# n1: 2
# n2: 3
# n3: 4
# Sum of Values: 9.0

# %% [markdown]
# **Task: Create a function that finds the highest number from any amount of scores**

# %%
# Solution:
def highest_score(*args):
  return("Highest Score: "+str(max(args)))
#args = [1,2,3,4,5] ## given values
args = [float(input("n1: ")),float(input("n2: ")),float(input("n3: "))]  ## User inputs
print(highest_score(*args))
# Out:
# n1: 2
# n2: 3
# n3: 4
# Highest Score: 4.0

# %% [markdown]
# **Task: Create a function that calculates the average of any amount of numbers**

# %%
# Solution:
import builtins  # was getting error for length funtion before importing builtins

def avg_score(*args):
  total = builtins.sum(args)
  count = builtins.len(args)
  average = total/count
  return(f"Average Value: {average}")
args = [1,2,3,4,5] ## given values
#args = [float(input("n1: ")),float(input("n2: ")),float(input("n3: "))]  ## User inputs
print(f"{avg_score(*args)}")
# Out:
# Average Value: 3.0

# %% [markdown]
# **Function with Keyword Arguments :**
#
# **Task: Create a function book_info(title, author, year=2025) that prints the book details. Call it using positional and keyword arguments.**

# %%
# Solution:
def book_info(title, author, year):
  return(f"Title: {title}, Author: {author}, Year: {year}")
title = str(input("Enter Title: "))
auther = "Maira Afaq"
year = 2025
print(book_info(title,auther,year))
# Out:
# Enter Title: Cardiff
# Title: Cardiff, Author: Maira Afaq, Year: 2025
